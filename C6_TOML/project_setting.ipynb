# %%
import toml

with open("config.toml", "r") as f:
    config = toml.load(f)

print(config)
# Out:
# {'system': {'polymer': 'polyethylene', 'chain_length': 50}, 'simulation': {'method': 'MD', 'temperature': 300, 'pressure': 1.0}, 'forcefield': {'type': 'GAFF2'}}

# %%
T = config["simulation"]["temperature"]
print(T)
# Out:
# 300

# %%
import toml

with open("output.toml", "w") as f:
    toml.dump(config, f)
